# %% [markdown]
# # Datos.
#
# -  Presión Parcial del $SO_2$ en el aire: $P_1 = 4 \ kPa$
# -  Condiciones de operación: 30 °C y 1 atm.
# -  Presión Parcial para el $SO_2$ sobre una solución acuosa a 30 °C.
#
# |Número de dato|g $SO_2$ / 100 g $H_2O$|Presión parcial de $SO_2$ (kPa)|
# |:---:|:---:|:---:|
# |1|0,01|0,016|
# |2|0,05|0,224|
# |3|0,1|0,616|
# |4|0,15|1,076|
# |5|0,2|1,573|
# |6|0,25|2,093|
# |7|0,3|2,640|
# |8|0,4|3,773|
# |9|0,5|4,946|
# |10|1|11,159|
# |11|2|24,398|
# |12|3|37,997|
# |13|4|51,862|
# |14|5|66,128|
# |15|6|80,260|
#
# -  Valor de la constante R: $8.314 \ \frac{kPa\cdot m^3}{kmol\cdot K} = 8.314 \times 10^{-3} \ \frac{kPa\cdot m^3}{mol\cdot K}$
# -  Se asume que el flujo volumétrico ($\dot{V}$) del del gas es constante en la entrada y salida: $0.037 \ \frac{m^3}{s}$
#
# ## Valores conocidos.
#
# -  Flujo de aire.
# -  Composición de ingreso del aire.
# -  Composición de salida del aire.
# -  Composición de ingreso del agua.
# -  Presión y temperatura de operación del sistema.
#
# ## Valores desconocidos.
#
# -  Flujo de agua.
# -  Diámetro y altura de la torre.
#
# ## Propiedades investigadas para el gas y líquido.
#
# -  Densidad del gas ($\rho_g$): $1.21 \ \frac{kg}{m^3}$
# -  Viscosidad ($\mu_g$): $1.75\times10^{-5} \ \frac{N\cdot s}{m^2}$
# -  Difusividad del gas ($D_g$): $1.23\times10^{-5} \ \frac{m^2}{s}$
# -  Difusividad del líquido ($D_L$): $1.7\times10^{-9} \ \frac{m^2}{s}$
# -  Viscosidad del agua ($\mu_w$): $1.0 \times 10^{-3} \ \frac{N \cdot s}{m^2}$
# -  Densidad del agua ($\rho_w$): $997 \ \frac{kg}{m^3}$
# -  Gravedad ($g$): $9.81 \ \frac{m}{s^2}$
# -  Temperatura (T): $303.15 \ K$
#
# Valores obtenidos de "Remove Sulfur Dioxide from Flue Gases to Obtain Sulfuric Acid through Electrodialysis Enrichment"(Yongtao et al., 2015), "Removal of Nitrogen Dioxide and Sulfur Dioxide from Air Streams by Absorption in Urea Solution"(Barbooti et al., 2011), "Perry´s chemical engineering handbook 9ed"(Green & Southard, 2019) y "Perry´s chemical engineering handbook 7ed" (Perry et al., 1997).
#
# ## Diagrama.

# %% [markdown]
# # Parte I.
#
# ## Obtención del diámetro de la columna.
#
# Para obtener el valor del diámetro, se considerará la siguiente fórmula y las propiedades para el gas previamente mencionadas, se evalua la siguiente ecuación, para obtener un valor para el Número de Reynolds que cumpla con: $2100 \leq Re \leq 35000$. (Li et al., 2012)
#
# $$Re_g = \frac{\rho_g \cdot u \cdot D}{\mu_g}$$
#
# De la cual se considera que:
#
# $$u = \frac{\dot{V}}{A_{Transversal}}$$
#
# Donde:
#
# $$A_{Transversal} = \frac{\pi \cdot D^2}{4}$$
#
# Sustituyendo las consideraciones tendremos lo siguiente:
#
# $$Re_g = \frac{\rho_g \cdot \dot{V} \cdot D}{\mu_g \cdot A_{Transversal}}$$
#
# $$Re_g = \frac{\rho_g \cdot \dot{V} \cdot D}{\mu_g \cdot \frac{\pi \cdot D^2}{4}}$$
#
# La simplificación total de la ecuación tiene la siguiente forma:
#
# $$Re_g = \frac{\rho_g \cdot \dot{V} \cdot 4}{\mu_g \cdot \pi \cdot D}$$
#
# Con la ecuación obtenida, se grafica para evaluar y obtener el valor del número de Reynolds y el diámetro de la tubería. La evalución gráfica estará dada por el siguiente código:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

rho = 1.21 #kg/m3
mu = 1.75e-5 #Ns/m2
V = 0.037 #m3/s
pi = np.pi
D = np.arange(0.02, 0.82, 0.02)

def Re(D):
    return (rho * V * 4)/(mu * pi * D)

plt.figure(figsize=(12,5))
plt.plot(D, Re(D))
plt.xlabel("D [m]", fontsize=16)
plt.ylabel("Re", fontsize=16)
plt.title("Número de Reynols en función del diámetro de la columna.", fontsize=20)
plt.show()

TD = pd.DataFrame(Re(D), D, columns = ["Número de Reynolds"])
print("Los Resultados obtenidos por la evalución del número de Reynolds para cada posible diámetro está dado por: \n")
print(TD)

print("\nEl valor del diámetro para la columna de pared mojada a emplearse es de 0.4 m y el valor del número de Reynolds aproximado para el gas es: Re = " + str(round(Re(0.4),)) + ". Este flujo es turbulento y además cumple con estar dentro de los límites posteriormente definidos para el número de Reynolds.")
# Out:
# Los Resultados obtenidos por la evalución del número de Reynolds para cada posible diámetro está dado por:
#
#       Número de Reynolds
# 0.02       162865.526908
# 0.04        81432.763454
# 0.06        54288.508969
# 0.08        40716.381727
# 0.10        32573.105382
# 0.12        27144.254485
# 0.14        23266.503844
# 0.16        20358.190863
# 0.18        18096.169656
# 0.20        16286.552691
# 0.22        14805.956992
# 0.24        13572.127242
# 0.26        12528.117454
# 0.28        11633.251922
# 0.30        10857.701794
# 0.32        10179.095432
# 0.34         9580.325112
# 0.36         9048.084828
# 0.38         8571.869837
# 0.40         8143.276345
# 0.42         7755.501281
# 0.44         7402.978496
# 0.46         7081.109866
# 0.48         6786.063621
# 0.50         6514.621076
# 0.52         6264.058727
# 0.54         6032.056552
# 0.56         5816.625961
# 0.58         5616.052652
# 0.60         5428.850897
# 0.62         5253.726674
# ...

# %% [markdown]
# ## Flujos.
#
# Se toma el comportamiento del gas como un gas ideal. Con el que averiguo el flujo molar de entrada del $SO_2$:
#
# $$P_{SO_2 In}\dot{V} = \dot{J}_{SO_2}^{In}RT$$
#
# $$\dot{J}_{SO_2}^{In} = \frac{P_{SO_2 In}\dot{V}}{RT} = \frac{\left(4 \ kPa\right)\left(0.037 \ \frac{m^3}{s}\right)}{\left(8.314 \ \frac{kPa \cdot m^3}{kmol \cdot K}\right)\left(303.15 \ K\right)}$$
#
# $$\dot{J}_{SO_2}^{In} = 5.87 \times 10^{-5} \ \frac{kmol}{s}$$
#
# Como el enunciado nos indica que se debe eliminar el 90% del $SO_2$ presente en el aire. Podemos averiguar la cantidad de moles transferidos al agua, tomando el flujo molar de la entrada y multiplicandolo por el 90%, por lo que tendremos:
#
# $$\dot{J}_{SO_2}^{Tranferidos} = \dot{J}_{SO_2}^{In} \cdot 90 \% = 5.28 \times 10^{-5} \ \frac{kmol}{s} = 5.28 \times 10^{-2} \ \frac{mol}{s}$$
#
# Al conocer los moles transferidos al agua, se calcula el flujo molar en la salida de la columna:
#
# $$\dot{J}_{SO_2}^{Out} = \dot{J}_{SO_2}^{In} - \dot{J}_{SO_2}^{Tranferidos} = 0.59 \times 10^{-5} \ \frac{kmol}{s}$$
#
# Dado a que se asumió un flujo volumétrico constante a través de la columna. Aplicando la fórmula del gas ideal, se obtiende la presión parcial del $SO_2$ a la salida de la columna:
#
# $$P_{SO_2 Out} = \frac{\dot{J}_{SO_2}^{Out}RT}{\dot{V}} = \frac{\left(0.59 \times 10^{-5} \ \frac{kmol}{s}\right)\left(8.314 \ \frac{kPa \cdot m^3}{kmol \cdot K}\right)\left(303.15 \ K\right)}{0.037 \ \frac{m^3}{s}}$$
#
# $$P_{SO_2 Out} = 0.40 \ kPa$$
#
# ### Flujo del agua.
#
# Considerando que:
#
# - Masa molar del $SO_2$: $64.066 \ \frac{kg}{kmol}$
# - Masa molar del $H_2O$: $18.02 \ \frac{kg}{kmol}$
#
# Considerando la información brindada por la Tabla 1, se obtienen los valores de las fracciones molares de $SO_2$ asociados a cada dato brindado, por lo que tendremos la siguiente tabla:
#
# |Masa $SO_2$ (g/s)|Masa agua (g/s)|Moles $SO_2$ (mol/s)|Moles agua (mol/s)|Fracción molar de $SO_2$ en el agua|g $SO_2$/ 100g Agua|Presión parcial del $SO_2$ en el agua (kPa)|
# |:---:|:---:|:---:|:---:|:---:|:---:|:---:|
# |0,01|100|0,000156|5,5494|2,81E-05|0,01|0,016|
# |0,05|100|0,000780|5,5494|1,41E-04|0,05|0,224|
# |0,1|100|0,001561|5,5494|2,81E-04|0,1|0,616|
# |0,15|100|0,002341|5,5494|4,22E-04|0,15|1,076|
# |0,2|100|0,003122|5,5494|5,62E-04|0,2|1,573|
# |0,25|100|0,003902|5,5494|7,03E-04|0,25|2,093|
# |0,3|100|0,004683|5,5494|8,43E-04|0,3|2,64|
# |0,4|100|0,006244|5,5494|1,12E-03|0,4|3,773|
# |0,5|100|0,007804|5,5494|1,40E-03|0,5|4,946|
# |1|100|0,015609|5,5494|2,80E-03|1|11,159|
# |2|100|0,031218|5,5494|5,59E-03|2|24,398|
# |3|100|0,046827|5,5494|8,37E-03|3|37,997|
# |4|100|0,062436|5,5494|1,11E-02|4|51,862|
# |5|100|0,078045|5,5494|1,39E-02|5|66,128|
# |6|100|0,093653|5,5494|1,66E-02|6|80,26|
#
# Asimismo se toman el valor de los moles transferidos y los moles de agua que ingresa (flujo de agua) para averiguar los moles totales que salen en el líquido y la fracción molar del $SO_2$ en el agua, el cual está dado por:
#
# $$\dot{J}_{SO_2}^{Tranferidos} = M_{Disolución}^{Out} \cdot x_{SO_2}$$
#
# $$M_{Disolución}^{Out} = \frac{\dot{J}_{SO_2}^{Tranferidos}}{x_{SO_2}}$$
#
# Considerando que:
#
# $$M_{Disolución}^{Out} = \dot{J}_{SO_2}^{Tranferidos} + Flujo \ de \ agua \ \left(\frac{mol}{s}\right)$$
#
# Por lo tanto, interpolando para obtener los valores de las presiones parciales que se encuentran entre los conjuntos de datos 4 y 8 de la Tabla 1, tendremos la siguiente tabla:
#
# |Flujo de agua|Moles totales|Fracción molar de SO2 en el agua|Presión parcial del $SO_2$ en el agua (kPa)|
# |:---:|:---:|:---:|:---:|
# |47,09|47,14|1,12E-03|3,773|
# |50|50,0528|1,05E-03|3,495|
# |55|55,0528|9,59E-04|3,108|
# |60|60,0528|8,79E-04|2,786|
# |61|61,0528|8,65E-04|2,728|
# |62,58|62,63|8,43E-04|2,64|
# |64|64,0528|8,24E-04|2,567|
# |66|66,0528|7,99E-04|2,470|
# |68|68,0528|7,76E-04|2,378|
# |70|70,0528|7,54E-04|2,292|
# |72|72,0528|7,33E-04|2,210|
# |75,05|75,10|7,03E-04|2,093|
# |80|80,0528|6,60E-04|1,933|
# |85|85,0528|6,21E-04|1,790|
# |90|90,0528|5,86E-04|1,662|
# |93,90|93,95|5,62E-04|1,573|
# |95|95,0528|5,55E-04|1,549|
# |100|100,0528|5,28E-04|1,451|
# |105|105,0528|5,03E-04|1,362|
# |110|110,0528|4,80E-04|1,281|
# |115|115,0528|4,59E-04|1,208|
# |120|120,0528|4,40E-04|1,140|
# |125,07|125,12|4,22E-04|1,076|
#
# Con ayuda de un código en python, se grafica la presión parcial en función del flujo del agua, con los datos obtenidos en la Tabla 3. Por lo que el código está dado por:

# %%
#Nota: Este bloque de programación continua con la información y paquetes del primer bloque de programación.

#Se crean las listas con los datos a graficar.

#Datos flujo de agua en kmol/s
Fw = [3.773,3.495,3.108,2.786,2.728,2.64,2.567,2.470,2.378,2.292,2.210,2.093,1.933,1.790,1.662,1.573,1.549,1.451,1.362,1.281,1.208,1.140,1.076]

#Presiones parciales del SO2 en kPa
P = [47.09,50,55,60,61,62.58,64,66,68,70,72,75.05,80,85,90,93.90,95,100,105,110,115,120,125.07]

plt.figure(figsize=(12,5))
plt.plot(Fw, P)
plt.xlabel("Flujo de agua (mol/s)", fontsize=16)
plt.ylabel("Presión parcial de SO2 (kPa)", fontsize=16)
plt.title("Flujo de agua en función de la presión parcial de SO2.", fontsize=20)
plt.show()

# %% [markdown]
# Con los datos de la Tabla 3, representados en la gráfica del flujo de agua en funsión de la presión parcial del $SO_2$. Se selecciona un flujo de agua de $75.05 \ \frac{mol}{s}$, con el fin de poder tener un buen gradiente para el ejercicio. Asimismo, al seleccionar dicho flujo se aplica una presión parcial del $SO_2$ de $2.093 \ kPa$.
#
# ## Fuerza motriz.
#
# Con los valores obtenidos gracias al flujo de agua podemos calcular el valor para la fuerza motriz, la cual está dada por:
#
# $$\Delta P_{LM} = \frac{\Delta P_1 - \Delta P_2}{ln\left(\frac{\Delta P_1}{\Delta P_2}\right)}$$
#
# Donde los valores de para $\Delta P_1$ y $\Delta P_2$ están dados por:
#
# $$\Delta P_1 = P_{SO_2 In} - P_{SO_2 Out}^{H_2O} = 4 \ kPa - 2.093 \ kPa = 1.907 \ kPa$$
#
# $$\Delta P_2 = P_{SO_2 Out} - P_{SO_2 In}^{H_2O} = 0.40 \ kPa - 0 \ kPa = 0.40 \ kPa$$
#
# Averiguamos el valor para $\Delta P_{LM}$:
#
# $$\Delta P_{LM} = \frac{1.907 - 0.40}{ln\left(\frac{1.907}{0.40}\right)} = 0.965 \ kPa$$
#
# Con esto, podemos definir la siguiente ecuación:
#
# $$\dot{J}_{SO_2}^{Tranferidos}= K_GA\Delta P_{LM}$$
#
# Despejando para hallar el valor de A se obtiene la siguiente ecuación:
#
# $$A= \frac{\dot{J}_{SO_2}^{Tranferidos}}{K_G\Delta P_{LM}}$$
#
# ## Calculo de $K_G$
#
# Para averiguar el valor de A, debemos encontrar el valor para $K_G$, por lo que tendremos lo siguiente:
#
# ### Coeficientes locales para el líquido.
#
# Para fines de este trabajo se empleará un grosor de la película (L) de 0.145 mm, por ende el coeficiente de pleícula está dado por $\delta = 1.45 \times 10{-4} \ m$; (Karamian et al., 2019). Este está definido por la siguiente ecuación:
#
# $$\delta = 1.45 \times 10{-4} \ m = \left(\frac{3\mu_w\Gamma}{\rho_w^2g}\right)^\frac{1}{3}$$
#
# Despejando para hallar el valor de $\Gamma$, tenemos que:
#
# $$\delta^3 = \frac{3\mu_w\Gamma}{\rho_w^2g}$$
#
# $$\Gamma = \frac{\delta^3\rho_w^2g}{3\mu_w} = \frac{\left(1.45 \times 10{-4} \ m\right)^3\left(997 \ \frac{kg}{m^3}\right)^2\left(9.81 \ \frac{m}{s^2}\right)}{3\left(1.0 \times 10^{-3} \ \frac{N \cdot s}{m^2}\right)}$$
#
# $$\Gamma = 0.009909 \ \frac{kg^2}{N \cdot s^3}$$
#
# Con el valor obtenido para $\Gamma$ se averigua el número de Reynolds, que estará dado por la siguiente ecuación:
#
# $$Re_L = \frac{4\Gamma}{\mu_w}$$
#
# $$Re_L = \frac{4 \left(0.009909 \ \frac{kg^2}{N \cdot s^3}\right)}{1.0 \times 10^{-3} \ \frac{N \cdot s}{m^2}}$$
#
# $$Re_L = 39.64 \approx 39$$
#
# Dado a que el valor del número de Reynolds encontrado para el líquido es aproximadamente 39, por lo que se cumple lo siguiente: $Re < 100$. Por lo tanto, el valor para el número de Sherwood es: $Sh = 3.14$. (Green & Southard, 2019). Considerando la siguiente fórmula para el número de Sherwood, tenemos:
#
# $$Sh = \frac{k_L\delta}{D_L} = 3.14$$
#
# Despejando, obtenemos el valor para $k_L$:
#
# $$k_L = \frac{ShD_L}{\delta}=\frac{3.14\left(1.7\times10^{-9} \ \frac{m^2}{s}\right)}{\left(1.45 \times 10{-4} \ m\right)}$$
#
# $$k_L = 2.53\times10^{-5} \ \frac{m}{s}$$
#
# ### Coeficientes locales para el gas.
#
# Sabemos que el valor para el número de Reynolds es: $Re_g = 8143$ (flujo turbulento). Asimismo, se calcula el valor para el número de Schmidt para el gas, que está dado por la siguiente ecuación:
#
# $$Sc_g = \frac{\mu_g}{\rho_gD_g} = \frac{\left(1.75\times10^{-5} \ \frac{N\cdot s}{m^2}\right)}{\left(1.21 \ \frac{kg}{m^3}\right)\left(1.23\times10^{-5} \ \frac{m^2}{s}\right)}$$
#
# $$Sc_g = 1.1758$$
#
# Para el número de Sherwood, tendremos las siguientes expresiones, con las cuales, se despeja $k_g$.
#
# $$Sh = k_g\frac{D}{D_g} = 0.023\left(Re_g\right)^{0.83}\left(Sc_g\right)^{0.44}$$
#
# $$k_g = 0.023\left(Re_g\right)^{0.83}\left(Sc_g\right)^{0.44}\frac{D_g}{D}$$
#
# $$k_g = 0.023 \cdot \left(8143\right)^{0.83} \cdot \left(1.1758\right)^{0.44} \cdot \frac{\left(1.23\times10^{-5} \ \frac{m^2}{s}\right)}{\left(0.4 \ m\right)}$$
#
# $$k_g = 0.001338 \ \frac{m}{s}$$
#
# ### Constante de Henry.
#
# Para averiguar el valor de H, se tomarán los datos de la Tabla 2 y Tabla 3, para averiguar la concentración del $SO_2$ en el agua se emplea la siguiente fórmula:
#
# $$Cn_{SO_2}^{H_2O} = \frac{n_{SO_2}}{\frac{m_{H_2O} \ (kg)}{\rho_w}} = \frac{n_{SO_2}\rho_w}{m_{H_2O} \ (kg)}$$
#
# Donde:
#
# $$m_{H_2O} \ (kg) = \frac{Flujo \ de \ agua \ (mol) \cdot MM_{H_2O}}{1000}$$
#
# Para averiguar la concentración del $SO_2$ en el aire, se considera que los moles presentes en el agua son el 90% de lo que entra en el aire; por lo que, los moles de $SO_2$ en el aire están dados por:
#
# $$n_{SO_2}^{Air} = \frac{n_{SO_2}^{H_2O}}{90 \%} - n_{SO_2}^{H_2O}$$
#
# Por ende, los valores para la concentración del $SO_2$ en el aire, tenemos:
#
# $$Cn_{SO_2}^{Air} = \frac{n_{SO_2}^{Air}}{\dot{V}} = \frac{n_{SO_2}^{Air}}{0.037 \ \frac{m^3}{s}}$$
#
# Con las fórmulas anteriores e interpolando para obtener los valores de los moles de $SO_2$ en el agua para sus respectivas presiones parciales que se encuentran entre los conjuntos de datos 4 y 8 de la Tabla 1, encontramos los valores para las concentraciones de $SO_2$ en agua y aire, para averiguar el valor de H. Brindando como resultado la siguiente tabla:
#
# |Flujo de agua|Moles totales|Kilogramos de agua (kg/s)|Fracción molar de SO2 en el agua|Moles de $SO_2$ en el agua (mol/s)|Presión Parcial del $SO_2$ en el agua (kPa)|Concentración de $SO_2$ en el agua (mol/$m^3$)|Moles de $SO_2$ en el aire (mol/s)|Concentración de $SO_2$ en el aire (mol/$m^3$)|
# |:---:|:---:|:---:|:---:|:---:|:---:|:---:|:---:|:---:|
# |47,09|47,14|0,849|1,12E-03|0,006244|3,773|7,337|6,94E-04|1,88E-02|
# |50|50,0528|0,901|1,05E-03|0,005877|3,507|6,503|6,53E-04|1,76E-02|
# |55|55,0528|0,991|9,59E-04|0,005337|3,115|5,369|5,93E-04|1,60E-02|
# |60|60,0528|1,081|8,79E-04|0,004887|2,788|4,507|5,43E-04|1,47E-02|
# |61|61,0528|1,099|8,65E-04|0,004806|2,729|4,359|5,34E-04|1,44E-02|
# |62,58|62,63|1,128|8,43E-04|0,004683|2,64|4,140|5,20E-04|1,41E-02|
# |64|64,0528|1,153|8,24E-04|0,004579|2,567|3,958|5,09E-04|1,38E-02|
# |66|66,0528|1,189|7,99E-04|0,004440|2,469|3,722|4,93E-04|1,33E-02|
# |68|68,0528|1,225|7,76E-04|0,004309|2,378|3,506|4,79E-04|1,29E-02|
# |70|70,0528|1,261|7,54E-04|0,004185|2,291|3,308|4,65E-04|1,26E-02|
# |72|72,0528|1,297|7,33E-04|0,004068|2,209|3,126|4,52E-04|1,22E-02|
# |75,05|75,10|1,352|7,03E-04|0,003902|2,093|2,877|4,34E-04|1,17E-02|
# |80|80,0528|1,442|6,60E-04|0,003662|1,933|2,532|4,07E-04|1,10E-02|
# |85|85,0528|1,532|6,21E-04|0,003447|1,790|2,244|3,83E-04|1,04E-02|
# |90|90,0528|1,622|5,86E-04|0,003257|1,663|2,002|3,62E-04|9,78E-03|
# |93,90|93,95|1,692|5,62E-04|0,003122|1,573|1,840|3,47E-04|9,38E-03|
# |95|95,0528|1,712|5,55E-04|0,003086|1,550|1,797|3,43E-04|9,27E-03|
# |100|100,0528|1,802|5,28E-04|0,002931|1,451|1,622|3,26E-04|8,80E-03|
# |105|105,0528|1,892|5,03E-04|0,002791|1,362|1,470|3,10E-04|8,38E-03|
# |110|110,0528|1,982|4,80E-04|0,002663|1,281|1,340|2,96E-04|8,00E-03|
# |115|115,0528|2,072|4,59E-04|0,002547|1,207|1,225|2,83E-04|7,65E-03|
# |120|120,0528|2,162|4,40E-04|0,002440|1,139|1,125|2,71E-04|7,33E-03|
# |125,07|125,12|2,254|4,22E-04|0,002341|1,076|1,036|2,60E-04|7,03E-03|
#
# Con ayuda de un código en python, se grafica la Concentración de $SO_2$ en el aire en función de la Concentración de $SO_2$ en el agua. Por lo que el código está dado por:

# %%
#Nota: Este bloque de programación continua con la información y paquetes del primer bloque de programación.

#Se crean las listas con los datos a graficar.

#Datos Cn SO2 en el agua en mol/m3
Cnw = [7.337,6.503,5.369,4.507,4.359,4.140,3.958,3.722,3.506,3.308,3.126,2.877,2.532,2.244,2.002,1.840,1.797,1.622,1.470,1.340,1.225,1.125,1.036]

#Datos Cn SO2 en el aire en mol/m3
Cna = [1.88e-2,1.76e-2,1.60e-2,1.47e-2,1.44e-2,1.41e-2,1.38e-2,1.33e-2,1.29e-2,1.26e-2,1.22e-2,1.17e-2,1.10e-2,1.04e-2,9.78e-3,9.38e-3,9.27e-3,8.80e-3,8.38e-3,8.00e-3,7.65e-3,7.33e-3,7.03e-3]

plt.figure(figsize=(15,7))
plt.plot(Cnw, Cna)
plt.xlabel("Concentración de SO2 en el agua (mol/m^3)", fontsize=16)
plt.ylabel("Concentración de SO2 en el aire (mol/m^3)", fontsize=16)
plt.title("Gráfica para la determinación de H para el SO2.", fontsize=20)
plt.show()

res = stats.linregress(Cnw,Cna)
m = round(res.slope,6)

print("\nEl valor de la pendiente de la gráfica es de: m = H = " + str(m))
# Out:
# El valor de la pendiente de la gráfica es de: m = H = 0.001902

# %% [markdown]
# Como se optienen un valor para la pendiente de 0.003009, este será el valor que posea la H. Con esto se puede calcular el coeficiente global ($K_G$) con la siguiente fórmula:
#
# $$\frac{1}{K_G} = \frac{1}{k_g}+\frac{H}{k_L}$$
#
# $$K_G = \left(\frac{1}{k_g}+\frac{H}{k_L}\right)^{-1} = \left(\frac{1}{0.001338 \ \frac{m}{s}}+\frac{0.001902}{2.53\times10^{-5} \ \frac{m}{s}}\right)^{-1}$$
#
# $$K_G = 1.22 \times10^{-3} \ \frac{m}{s}$$
#
# ## Cálculo de la altura de la columna.
#
# Con la siguiente fórmula (propuesta anteriormente), al poseer A despejado, se sustituye para hallar el valor da A; Por lo que tendremos lo siguiente:
#
# $$A = \frac{5.28\times10^{-2}}{\left(1.22 \times10^{-3}\right)\left(0.965\right)} = 44.85 \ m^2$$
#
# La expresión para A, de la cual se despeja la altura (h), es la siguiente:
#
# $$A = \pi D h$$
#
# Obtengo el valor de h:
#
# $$h = \frac{A}{\pi D} = \frac{44.85 \ m^2}{\pi \left(0.4 \ m\right)} = 35.69 \ m$$
#
# ## Respuesta.
#
# Para esta columna de pared mojada, se obtuvo que esta posee un diámetro de 0.4 m; asimismo, en esta se emplea un flujo de agua de 75.05  $\frac{mol}{s}$ y una altura de 35.69 m. Con el fin de lograr extraer el 90% de $SO_2$ que ingresa con el flujo de aire.

# %% [markdown]
# # Parte II.
#
# Se  cuenta  con  una  columna  de  pared  húmeda  de  10  cm  de  diámetro  y  15  m  de  altura  ¿será capaz este equipo de lograr el objetivo planteado y eliminar el 90% del $SO_2$ aire? Para esto se realiza lo siguiente:
#
# ## Datos.
#
# -  Diámetro (D): $10 \ cm = 0.1 \ m.$
# -  Altura (h): $15 \ m.$
# -  Debe cumplir con una extracción del 90% del $SO_2$ en el aire: $\dot{J}_{SO_2}^{Tranferidos} = 5.28 \times 10^{-2} \ \frac{mol}{s}$
#
# ## Resolución.
#
# Para determinar si los parámetros de la columna de pared húmeda propuesta cumple con los requerimientos, se tendrá la siguiente fórmula:
#
# $$\dot{J}_{SO_2}^{Tranferidos}= K_GA\Delta P_{LM}$$
#
# Donde tendremos que:
#
# -  Fuerza motriz ($\Delta P_{LM}$):
#
# $$\Delta P_{LM} = 0.965 \ kPa$$
#
# -  Coeficiente global de transferencia de masa ($K_G$):
#
# $$K_G = 1.22 \times10^{-3} \ \frac{m}{s}$$
#
# -  Área lateral de la columna (A):
#
# $$A = \pi D h = \pi \left(0.1 \ m\right) \left(15 \ m\right) = 4.71 \ m^2$$
#
# Calculamos el valor para los moles de $SO_2$ transferidos:
#
# $$\dot{J}_{SO_2}^{Tranferidos}= \left(1.22 \times10^{-3} \ \frac{m}{s}\right)\left(4.71 \ m^2\right)\left(0.965 \ kPa\right)$$
#
# $$\dot{J}_{SO_2}^{Tranferidos} = 5.55 \times10^{-3} \ \frac{mol}{s} \neq 5.28 \times10^{-2} \ \frac{mol}{s}$$
#
# ## Respuesta.
#
# Dado a que el resultado obtenido para los moles transferidos de la columna de pared mojada propuesta por el enunciado no es igual a $5.28 \times10^{-2} \ \frac{mol}{s}$, se concluye que dicha columna no cumple con el parámetro solicitado de extracción de $SO_2$ del aire. Lo que implica que el equipo no sería capaz de eliminar el 90% del $SO_2$ aire.
#
# # Información extra.
#
# Acontinuación se presenta la gráfica que relaciona la variación del diámetro y altura requeridos para que se cumpla una eliminación del 90% del $SO_2$ aire, por lo que se empleará la siguiente fórmula para dicha graficación:
#
# $$A= \pi D h = \frac{\dot{J}_{SO_2}^{Tranferidos}}{K_G\Delta P_{LM}}$$
#
# Por ende la fórmula para el valor de la altura (h) en función del diámetro (D) es:
#
# $$h(D) = \frac{\left(\frac{\dot{J}_{SO_2}^{Tranferidos}}{K_G\Delta P_{LM}}\right)}{\pi D}$$
#
# El código para dicha graficación es el siguiente:

# %%
D = np.arange(0.02, 0.82, 0.02)
KG = 1.22e-3 #m/s
PLM = 0.965 #kPa
J = 5.28e-2 #mol/s

def h(D):
    return ((J)/(KG*PLM))/(pi * D)

plt.figure(figsize=(12,5))
plt.plot(D, h(D))
plt.xlabel("D [m]", fontsize=16)
plt.ylabel("h [m]", fontsize=16)
plt.title("Altura de la columna en función del diámetro.", fontsize=20)
plt.show()

TH = pd.DataFrame(h(D), D, columns = ["Altura de la columna [m]"])
print("Los Resultados obtenidos por la evalución de la altura de la columna para cada posible diámetro está dado por: \n")
print(TH)
# Out:
# Los Resultados obtenidos por la evalución de la altura de la columna para cada posible diámetro está dado por:
#
#       Altura de la columna [m]
# 0.02                713.784167
# 0.04                356.892083
# 0.06                237.928056
# 0.08                178.446042
# 0.10                142.756833
# 0.12                118.964028
# 0.14                101.969167
# 0.16                 89.223021
# 0.18                 79.309352
# 0.20                 71.378417
# 0.22                 64.889470
# 0.24                 59.482014
# 0.26                 54.906474
# 0.28                 50.984583
# 0.30                 47.585611
# 0.32                 44.611510
# 0.34                 41.987304
# 0.36                 39.654676
# 0.38                 37.567588
# 0.40                 35.689208
# 0.42                 33.989722
# 0.44                 32.444735
# 0.46                 31.034094
# 0.48                 29.741007
# 0.50                 28.551367
# ...

# %% [markdown]
# # Bibliografía.
#
# -  Barbooti, M. M., Ibraheem, N. K., & Ankosh, A. H. (2011). Removal of Nitrogen Dioxide and Sulfur Dioxide from Air Streams by Absorption in Urea Solution. Journal of Environmental Protection, 02(02), 175–185. https://doi.org/10.4236/JEP.2011.22020
# -  Green, D. W., & Southard, M. Z. (2019). Perry´s chemical engineering handbook (G. Don W. (ed.); 9th ed.). McGraw-Hill Education.
# -  Karamian, S., Mowla, D., & Esmaeilzadeh, F. (2019). The effiect of various nanofluids on absorption intensification of CO2/SO2 in a single-bubble column. Processes, 7(7). https://doi.org/10.3390/pr7070393
# -  Li, X., Zhu, C., Lu, S., & Ma, Y. (2012). MASS TRANSFER OF SO 2 ABSORPTION WITH AN INSTANTANEOUS CHEMICAL REACTION IN A BUBBLE COLUMN. Brazilian Journal of Chemical Engineering, 30(03), 551–562. www.abeq.org.br/bjche
# -  Perry, R. H., Maloney, J. O., & Green, D. W. (1997). Perry’s chemical engineers’ handbook. https://books.google.com/books/about/Perry_s_Chemical_Engineers_Handbook.html?id=9h69MgEACAAJ
# -  Yongtao, Y., NingPing, Guangfei, Q., Junyan, L., & Qian, Z. (2015). Remove Sulfur Dioxide from Flue Gases to Obtain Sulfuric Acid through Electrodialysis Enrichment. Journal of The Electrochemical Society, 162(9), E141–E147. https://doi.org/10.1149/2.0591509JES
